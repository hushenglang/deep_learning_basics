# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline

# %% [markdown]
# ### load data and get correlations to save it as CSV file

# %%
df = pd.read_csv('sp500_joined_closes.csv')

# %%
df = df.set_index("Date")
df = df.fillna(0)

# %%
df.tail()
# Out:
#                MMM    ABT   ABBV     ACN   ATVI     AYI    ADBE    AMD  \
# Date
# 2016-12-23  178.75  38.42  62.34  117.48  36.50  234.92  105.02  11.58
# 2016-12-27  178.92  38.60  62.50  117.55  36.53  235.59  104.98  12.07
# 2016-12-28  178.08  38.22  62.27  116.61  36.43  230.80  103.77  11.55
# 2016-12-29  178.41  38.31  62.73  117.01  36.48  232.79  103.68  11.59
# 2016-12-30  178.57  38.41  62.62  117.13  36.11  230.86  102.95  11.34
#
#                AAP    AES  ...     WYNN    XEL    XRX   XLNX     XL    XYL  \
# Date                       ...
# 2016-12-23  170.89  11.73  ...    88.34  40.67  35.80  60.56  37.99  51.01
# 2016-12-27  171.84  11.86  ...    88.24  40.73  35.76  61.24  38.03  50.86
# 2016-12-28  170.42  11.64  ...    87.08  40.29  35.04  60.63  37.70  49.94
# 2016-12-29  170.28  11.70  ...    87.17  40.94  34.88  60.74  37.26  49.77
# 2016-12-30  169.12  11.62  ...    86.51  40.70  34.92  60.37  37.26  49.52
#
#               YUM     ZBH   ZION    ZTS
# Date
# ...

# %%
corr = df.corr()
corr.to_csv("sp500corr.csv")

# %% [markdown]
# ### load correlation data and visualize it with heat map plot in seaborn

# %%
sns.heatmap(corr)

# %% [markdown]
# ### visualize the correlation between Amzon and other stocks

# %%
cols = corr.nlargest(10, "AMZN")['AMZN'].index

# %%
#scatterplot pair plot
sns.set()
sns.pairplot(df[cols])
